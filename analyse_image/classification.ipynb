# %%
import pandas as pnd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras

tf.config.set_visible_devices([], 'GPU')

#Définition de la longueur et de la largeur de l'image
LONGUEUR_IMAGE = 28
LARGEUR_IMAGE = 28

#Chargement des images
observations_entrainement = pnd.read_csv('datas/fashion-mnist_train.csv')

# %%
#On exclut la première colonne (les labels) pour constituer un tableau de pixels
X = np.array(observations_entrainement.iloc[:, 1:])

premiereImage = X[0]
premiereImage = premiereImage.reshape([LONGUEUR_IMAGE,LARGEUR_IMAGE])
plt.imshow(premiereImage)
plt.show()

# %%
#On crée des catégories à l'aide du module Keras
y = keras.utils.to_categorical(np.array(observations_entrainement.iloc[:,0]))
#Répartition des données d'entrainement en données d'apprentissage et données de validation
#80% de donnée d'apprentissage et 20% de donnée de validation
X_apprentissage, X_validation, y_apprentissage, y_validation = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
# On redimensionne les images au format 28*28 et on réalise un scaling sur les données des pixels
X_apprentissage = X_apprentissage.reshape(X_apprentissage.shape[0], 
                                          LARGEUR_IMAGE, 
                                          LONGUEUR_IMAGE, 1)
X_apprentissage = X_apprentissage.astype('float32')
X_apprentissage /= 255

X_validation = X_validation.reshape(X_validation.shape[0], 
                                    LARGEUR_IMAGE, 
                                    LONGUEUR_IMAGE, 1)
X_validation = X_validation.astype('float32')
X_validation /= 255

# %%
#Preparation des données de tests
observations_test = pnd.read_csv('datas/fashion-mnist_test.csv')
X_test = np.array(observations_test.iloc[:, 1:])
y_test = tf.keras.utils.to_categorical(np.array(observations_test.iloc[:, 0]))
X_test = X_test.reshape(X_test.shape[0], 
                        LARGEUR_IMAGE, 
                        LONGUEUR_IMAGE, 1)
X_test = X_test.astype('float32')
X_test /= 255

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D

# On spécifie les dimensions de l'image d'entrée
dimentionImage = (LARGEUR_IMAGE, LONGUEUR_IMAGE, 1)

# On crée le réseau de neurones couche par couche
reseauNeurone1Convolution = Sequential()

# Ajout de la couche d'entrée
reseauNeurone1Convolution.add(Input(shape=dimentionImage))

#1- Ajout de la couche de convolution comportant
# 32 filtres de de taille 3x3 (Kernel) parcourant l'image
# Une fonction d'activation de type ReLU (Rectified Linear Activation)
# Une image d'entrée de 28px * 28 px 
reseauNeurone1Convolution.add(Conv2D(32, 
                                     kernel_size=(3, 3), 
                                     activation='relu'))

#2- Définition de la fonction de pooling avec une fenêtre de 2px sur 2 px
reseauNeurone1Convolution.add(MaxPooling2D(pool_size=(2, 2)))

#3- Ajout d'une fonction d'ignorance
reseauNeurone1Convolution.add(Dropout(0.2))

#5 - On transforme en une seule ligne
reseauNeurone1Convolution.add(Flatten())

#6 - Ajout d'un réseau de neurones composé de 128 neurones avec 
# une fonction d'activation de type ReLU
reseauNeurone1Convolution.add(Dense(128, activation='relu'))

#7 - Ajout d'un réseau de neurones composé de 10 neurones avec une 
# fonction d'activation de type softmax
reseauNeurone1Convolution.add(Dense(10, activation='softmax'))

# %%
reseauNeurone1Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

# %%
historique_apprentissage = reseauNeurone1Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8118 - loss: 0.5405 - val_accuracy: 0.8477 - val_loss: 0.4227
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.8730 - loss: 0.3629 - val_accuracy: 0.8809 - val_loss: 0.3395
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8857 - loss: 0.3234 - val_accuracy: 0.8848 - val_loss: 0.3297
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8954 - loss: 0.2929 - val_accuracy: 0.8943 - val_loss: 0.3002
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.9014 - loss: 0.2770 - val_accuracy: 0.8968 - val_loss: 0.2962
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.9088 - loss: 0.2584 - val_accuracy: 0.9037 - val_loss: 0.2724
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.9114 - loss: 0.2446 - val_accuracy: 0.9046 - val_loss: 0.2690
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.9159 - loss: 0.2321 - val_accuracy: 0.9052 - val_loss: 0.2622
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9201 - loss: 0.2196 - val_accuracy: 0.9075 - val_loss: 0.2556
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.9254 - loss: 0.2083 - val_accuracy: 0.9109 - val_loss: 0.2507

# %%
evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Erreur: 0.23809374868869781
# Précision: 0.9164000153541565

# %%
plt.plot(historique_apprentissage.history['accuracy'])
plt.plot(historique_apprentissage.history['val_accuracy'])
plt.title('Précision du modèle')
plt.ylabel('Précision')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()
# Plot training & validation loss values
plt.plot(historique_apprentissage.history['loss'])
plt.plot(historique_apprentissage.history['val_loss'])
plt.title('Erreur')
plt.ylabel('Erreur')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

generateur_images = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    shear_range=0.3,
    height_shift_range=0.08,
    zoom_range=0.08)

# %%
nouvelles_images_apprentissage = generateur_images.flow(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256)

nouvelles_images_validation = generateur_images.flow(
    X_validation, 
    y_validation,
    batch_size=256)

historique_apprentissage = reseauNeurone1Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 77ms/step - accuracy: 0.8237 - loss: 0.4739 - val_accuracy: 0.8462 - val_loss: 0.4161
# Epoch 2/50
#   1/187 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.8477 - loss: 0.3792
# c:\Users\Nermine\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8477 - loss: 0.3792 - val_accuracy: 0.8458 - val_loss: 0.4185
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.8450 - loss: 0.4159 - val_accuracy: 0.8533 - val_loss: 0.3989
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7969 - loss: 0.5375 - val_accuracy: 0.8586 - val_loss: 0.3907
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.8528 - loss: 0.3968 - val_accuracy: 0.8702 - val_loss: 0.3634
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8594 - loss: 0.3096 - val_accuracy: 0.8599 - val_loss: 0.3790
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - accuracy: 0.8588 - loss: 0.3823 - val_accuracy: 0.8580 - val_loss: 0.3820
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8438 - loss: 0.3993 - val_accuracy: 0.8605 - val_loss: 0.3744
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.8659 - loss: 0.3645 - val_accuracy: 0.8607 - val_loss: 0.3622
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8477 - loss: 0.4050 - val_accuracy: 0.8616 - val_loss: 0.3646
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - accuracy: 0.8689 - loss: 0.3539 - val_accuracy: 0.8704 - val_loss: 0.3499
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8867 - loss: 0.2796 - val_accuracy: 0.8706 - val_loss: 0.3544
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.8711 - loss: 0.3482 - val_accuracy: 0.8759 - val_loss: 0.3374
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8789 - loss: 0.3274 - val_accuracy: 0.8729 - val_loss: 0.3482
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.8747 - loss: 0.3416 - val_accuracy: 0.8754 - val_loss: 0.3388
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8828 - loss: 0.3263 - val_accuracy: 0.8697 - val_loss: 0.3499
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 84ms/step - accuracy: 0.8747 - loss: 0.3369 - val_accuracy: 0.8742 - val_loss: 0.3420
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8906 - loss: 0.2846 - val_accuracy: 0.8736 - val_loss: 0.3397
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.8783 - loss: 0.3274 - val_accuracy: 0.8815 - val_loss: 0.3247
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8906 - loss: 0.2888 - val_accuracy: 0.8787 - val_loss: 0.3337
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.8771 - loss: 0.3285 - val_accuracy: 0.8852 - val_loss: 0.3177
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9180 - loss: 0.2542 - val_accuracy: 0.8826 - val_loss: 0.3185
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.8816 - loss: 0.3214 - val_accuracy: 0.8779 - val_loss: 0.3260
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9023 - loss: 0.2870 - val_accuracy: 0.8776 - val_loss: 0.3345
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 79ms/step - accuracy: 0.8827 - loss: 0.3162 - val_accuracy: 0.8874 - val_loss: 0.3089
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8672 - loss: 0.3537 - val_accuracy: 0.8799 - val_loss: 0.3192
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.8836 - loss: 0.3123 - val_accuracy: 0.8820 - val_loss: 0.3146
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8789 - loss: 0.2827 - val_accuracy: 0.8818 - val_loss: 0.3194
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.8857 - loss: 0.3083 - val_accuracy: 0.8844 - val_loss: 0.3109
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8906 - loss: 0.3034 - val_accuracy: 0.8827 - val_loss: 0.3168
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.8856 - loss: 0.3041 - val_accuracy: 0.8867 - val_loss: 0.3072
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8633 - loss: 0.3613 - val_accuracy: 0.8862 - val_loss: 0.3094
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.8878 - loss: 0.3020 - val_accuracy: 0.8910 - val_loss: 0.3019
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8672 - loss: 0.3670 - val_accuracy: 0.8893 - val_loss: 0.3059
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.8890 - loss: 0.3008 - val_accuracy: 0.8877 - val_loss: 0.3055
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8750 - loss: 0.3255 - val_accuracy: 0.8907 - val_loss: 0.2996
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.8886 - loss: 0.3009 - val_accuracy: 0.8897 - val_loss: 0.3001
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9141 - loss: 0.2300 - val_accuracy: 0.8882 - val_loss: 0.2989
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.8913 - loss: 0.2941 - val_accuracy: 0.8892 - val_loss: 0.3019
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9102 - loss: 0.2344 - val_accuracy: 0.8894 - val_loss: 0.3025
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.8914 - loss: 0.2929 - val_accuracy: 0.8871 - val_loss: 0.3022
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8984 - loss: 0.2828 - val_accuracy: 0.8888 - val_loss: 0.2982
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.8940 - loss: 0.2862 - val_accuracy: 0.8879 - val_loss: 0.2990
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8867 - loss: 0.2897 - val_accuracy: 0.8900 - val_loss: 0.2979
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.8926 - loss: 0.2916 - val_accuracy: 0.8928 - val_loss: 0.2899
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8867 - loss: 0.3216 - val_accuracy: 0.8919 - val_loss: 0.2989
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.8934 - loss: 0.2849 - val_accuracy: 0.8905 - val_loss: 0.2983
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8789 - loss: 0.3284 - val_accuracy: 0.8870 - val_loss: 0.3065
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8957 - loss: 0.2810 - val_accuracy: 0.8911 - val_loss: 0.3000
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9023 - loss: 0.2986 - val_accuracy: 0.8888 - val_loss: 0.2985
# Erreur : 0.23516523838043213
# Précision: 0.9139999747276306

# %%
#Sauvegarde du modèle
# Serialisation du modèle 
model_json = reseauNeurone1Convolution.to_json() 
with open("modele/modele.json", "w") as json_file:
    json_file.write(model_json)
    
# Serialisation des poids
reseauNeurone1Convolution.save_weights("modele/modele.weights.h5")
print("Modèle sauvegardé !")
# Out:
# Modèle sauvegardé !

# %%
from keras.layers import BatchNormalization

reseauNeurones4Convolution = Sequential()

reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=dimentionImage))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Flatten())
reseauNeurones4Convolution.add(Dense(512, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))

reseauNeurones4Convolution.add(Dense(128, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))
# Out:
# c:\Users\Nermine\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
reseauNeurones4Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

# %%
historique_apprentissage = reseauNeurone1Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9303 - loss: 0.1917 - val_accuracy: 0.9184 - val_loss: 0.2294
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.9391 - loss: 0.1660 - val_accuracy: 0.9228 - val_loss: 0.2152
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9445 - loss: 0.1520 - val_accuracy: 0.9233 - val_loss: 0.2114
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9485 - loss: 0.1396 - val_accuracy: 0.9253 - val_loss: 0.2088
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9544 - loss: 0.1279 - val_accuracy: 0.9255 - val_loss: 0.2073
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9577 - loss: 0.1185 - val_accuracy: 0.9235 - val_loss: 0.2155
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9582 - loss: 0.1135 - val_accuracy: 0.9267 - val_loss: 0.2102
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9634 - loss: 0.1036 - val_accuracy: 0.9269 - val_loss: 0.2134
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9645 - loss: 0.0974 - val_accuracy: 0.9230 - val_loss: 0.2215
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9678 - loss: 0.0903 - val_accuracy: 0.9261 - val_loss: 0.2208

# %%
evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Erreur: 0.21386592090129852
# Précision: 0.9307000041007996
